# %%
# %load_ext autoreload
# %autoreload 2

# %%
from feat_to_model_eval import feat_model_eval

# %%
import pandas as pd

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0         NaN   0.0     ...          7        1180
# 1      7242     2.0         0.0   0.0     ...          7        2170
# 2     10000     1.0         0.0   0.0     ...          6         770
# 3      5000     1.0         0.0   0.0     ...          7        1050
# 4      8080     1.0         0.0   0.0     ...          8        1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df_small = df[['sqft_living', 'grade', 'sqft_living15', 'price']].copy()

# %%
df_small.head()
# Out:
#    sqft_living  grade  sqft_living15     price
# 0         1180      7           1340  221900.0
# 1         2570      7           1690  538000.0
# 2          770      6           2720  180000.0
# 3         1960      7           1360  604000.0
# 4         1680      8           1800  510000.0

# %%
fme = feat_model_eval().eval('price', df_small)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.535
# Method:                 Least Squares   F-statistic:                     8282.
# Date:                Wed, 17 Apr 2019   Prob (F-statistic):               0.00
# Time:                        11:11:43   Log-Likelihood:            -2.9912e+05
# No. Observations:               21597   AIC:                         5.983e+05
# Df Residuals:                   21593   BIC:                         5.983e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
from feat_to_model_eval import model_eval

# %%
model_eval('price', df)

# %%
import sklearn.model_selection as skmod

# %%
skmod.KFold()
