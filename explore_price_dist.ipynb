# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
plt.figure(figsize=(15,8))
plt.hist(df.price, bins=100)
plt.show()

# %%
df.price.plot.hist(density=True, bins=50)
df.price.plot.kde(c='red')
plt.show()

# %%
df.price.mean()
# Out:
# 540296.5735055795

# %%
df.price.median()
# Out:
# 450000.0

# %%
price_log = np.log(df.price)

# %%
plt.figure(figsize=(15,8))
plt.hist(price_log, bins=100)
plt.show()

# %%
price_log.mean()
# Out:
# 13.048210941923953

# %%
price_log.median()
# Out:
# 13.017002861746503

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-3580e57b55d8> in <module>()
# ----> 1 prices.median()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
price_mean_norm = (prices - prices.mean())/(prices.max()-prices.min())
price_minmax_norm = (prices - prices.min())/(prices.max()-prices.min())

# %%
plt.figure(figsize=(15, 8))
plt.hist(price_mean_norm, bins=100)
plt.show()

# %%
plt.hist(price_minmax_norm, bins=100)
plt.show()

# %%
'''log seems to be the most effective normalizer for price feature'''
# Out:
# 'log seems to be the most effective normalizer for price feature'

# %%
'''now to check for outliers'''
# Out:
# 'now to check for outliers'

# %%
plt.figure(figsize=(8,8))
plt.boxplot(df.price)
plt.show()

# %%
df.price.describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
df.price.quantile(.001)
# Out:
# 95894.0

# %%
df.price.quantile(.01)
# Out:
# 154000.0

# %%
df.price.quantile(.99)
# Out:
# 1970000.0

# %%
df.price.quantile(.999)
# Out:
# 3480600.000000341

# %%
'''maybe use prices from lower 1th percentile to 99th percentile'''
# Out:
# 'maybe use prices from lower 1th percentile to 99th percentile'

# %%
plt.figure(figsize=(10,10))
plt.boxplot(price_log)
plt.show()

# %%
price_log.quantile(.01)
# Out:
# 11.944707881395768

# %%
price_log.quantile(.001)
# Out:
# 11.47096917616234

# %%
price_log.quantile(.99)
# Out:
# 14.493544100714171

# %%
price_log.quantile(.999)
# Out:
# 15.062492827104567

# %%
'''maybe less need to remove outliers with log of price'''
# Out:
# 'maybe less need to remove outliers with log of price'
